# %%
# Load Model, Scaler & Encoders

import pickle
import pandas as pd

# Load model (classifier)
with open("classifier.pkl", "rb") as f:
    model = pickle.load(f)

# Load fertilizer label encoder
with open("fertilizer.pkl", "rb") as f:
    fertilizer_encoder = pickle.load(f)

# %%
sample = pd.DataFrame([{
    "Temperature": 5,
    "Humidity": 55,
    "Moisture": 10,
    "Soil_Type": 1,   # <-- replace with correct encoded value
    "Crop_Type": 2,   # <-- replace with correct encoded value
    "Nitrogen": 10,
    "Potassium": 25,
    "Phosphorous": 80
}])

# %%
# # Predict fertilizer class (encoded number)
# prediction = model.predict(sample)

# # Decode to fertilizer name
# fertilizer_name = fertilizer_encoder.inverse_transform(prediction)

# print("🌱 Recommended Fertilizer:", fertilizer_name[0])

# %%
fertilizer_info = {
    "10-10-2010": "Balanced NPK fertilizer (10% Nitrogen, 10% Phosphorus, 10% Potassium) – good for overall crop growth.",
    "10-26-26": "High phosphorus and potassium – promotes strong root development and better flowering/fruiting.",
    "14-14-14": "Balanced NPK – supports uniform growth, suitable for general-purpose farming.",
    "14-35-14": "Very high phosphorus – recommended for root crops and flowering plants needing strong root systems.",
    "15-15-15": "Balanced NPK – helps with vegetative growth and early plant establishment.",
    "17-17-17": "Balanced NPK fertilizer – boosts overall crop growth and productivity.",
    "20-20": "Balanced but stronger – provides higher NPK for nutrient-demanding crops.",
    "28-28": "High balanced NPK – used in nutrient-intensive farming for faster crop growth.",
    "DAP": "Diammonium Phosphate – rich in nitrogen and phosphorus, promotes root growth and seedling establishment.",
    "Potassium chloride": "Muriate of Potash – high potassium content, improves crop quality, fruit size, and disease resistance.",
    "Potassium sulfate.": "Sulfate of Potash – potassium + sulfur, good for crops sensitive to chloride (like tobacco, fruits, vegetables).",
    "Superphosphate": "Single Super Phosphate – high in phosphorus, encourages root growth and flowering.",
    "TSP": "Triple Super Phosphate – concentrated phosphorus source, used for strong root and flower development.",
    "Urea": "Very high nitrogen fertilizer – promotes leafy growth, best for cereals like wheat, rice, and maize."
}

# %%
fertilizer_safety = {
    "10-10-2010": "Wear gloves and avoid inhaling dust. Do not overapply as it can harm soil balance.",
    "10-26-26": "Handle with gloves and apply as per soil test. High salts can burn plants if overused.",
    "14-14-14": "Store in a dry place. Avoid direct skin contact. Wash hands after use.",
    "14-35-14": "High phosphorus content – avoid runoff into water sources. Use gloves and mask.",
    "15-15-15": "Avoid inhalation of dust. Wash hands after application. Do not mix with strong acids.",
    "17-17-17": "Balanced fertilizer – safe with normal handling. Always wear gloves while spreading.",
    "20-20": "Apply carefully as it is concentrated. Avoid inhalation of dust particles.",
    "28-28": "Strong fertilizer – use mask and gloves during handling. Avoid contact with eyes and mouth.",
    "DAP": "Irritant to skin and eyes. Use gloves and mask. Do not apply too close to seeds.",
    "Potassium chloride": "Can irritate skin. Avoid overuse as it increases soil salinity.",
    "Potassium sulfate.": "Safer than potassium chloride but can still irritate skin/eyes. Use gloves.",
    "Superphosphate": "May cause irritation to skin, eyes, and lungs. Avoid inhaling dust.",
    "TSP": "Concentrated phosphate – wear protective gloves, mask, and avoid runoff into water.",
    "Urea": "Releases ammonia fumes – use in open air. Avoid direct contact and wash hands after use.",
    
    # Default guideline for any missing fertilizer
    "default": "Handle with care. Wear gloves and mask while applying. Avoid overuse and wash hands after handling."
}

# %%
# Predict
prediction = model.predict(sample)
fert_name = fertilizer_encoder.inverse_transform(prediction)[0]
info = fertilizer_info.get(fert_name, "No info available")
safety = fertilizer_safety.get(fert_name, fertilizer_safety["default"])

print("🌱 Recommended Fertilizer:", fert_name)
print("ℹ️ Info:", info)
print("⚠️ Safety Guidelines:", safety)
# Out:
# 🌱 Recommended Fertilizer: DAP
# ℹ️ Info: Diammonium Phosphate – rich in nitrogen and phosphorus, promotes root growth and seedling establishment.
# ⚠️ Safety Guidelines: Irritant to skin and eyes. Use gloves and mask. Do not apply too close to seeds.
